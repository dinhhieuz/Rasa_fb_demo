# %%
import json
import random, string

my_json = {
        'id': '109523555015462', 
        'time': 1647053291651, 
        'messaging': [
            {
                'sender': {'id': '4857932260991004'}, 
                'recipient': {'id': '109523555015462'}, 
                'timestamp': 1647053291403, 
                'message': {
                    "type": "one_time_notif_req",
                    "payload": "đăng ký gữi tự động lương",
                    "one_time_notif_token": "7089066037755021622"
                }
            }
        ]
    }
if 'optin' in my_json['messaging'][0].keys():
    if my_json['messaging'][0]["optin"]["type"] == 'one_time_notif_req':
        import random, string
        random_word = lambda length: ''.join(random.choice(string.ascii_lowercase) for i in range(length))
        my_json['messaging'][0]['message'] = {
                        "mid": 'm_{0}-{1}_{2}-{3}'.format(random_word(10), random_word(14), random_word(29), random_word(30)),
                        "text": my_json['messaging'][0]["optin"]["payload"] + ' | ' + my_json['messaging'][0]["optin"]["one_time_notif_token"]
                    }
        del my_json['messaging'][0]['optin']
else:
    print('1')
# Out:
# 1

# %%
print('\x1b[0;30;43m' + 'Success!' + '\x1b[0m')
# Out:
# Success!

# %%
len('SKdH3g163ori1WSyPyHWqg6nlZTcLA')
# Out:
# 30

# %%
import random, string
randomword = lambda length: ''.join(random.choice(string.ascii_lowercase) for i in range(length))
a = 'm_{0}-{1}_{2}-{3}'.format(randomword(10), randomword(14), randomword(29), randomword(30))
print(len(a))
# Out:
# 88

# %%
a = {
        'id': '109523555015462', 
        'time': 1647053291651, 
        'messaging': [
            {
                'sender': {'id': '4857932260991004'}, 
                'recipient': {'id': '109523555015462'}, 
                'timestamp': 1647053291403, 
                'optin': {
                    'mid': 'm_E3Z93x_Yza_PWqIlyV4JDn2zI_O641bhB3KEhNDGS9e0SsmYb8KNnOYlfYoIbCmIt16QD0Z0quM2sgoKRNIIrw', 
                    'text': 'chào'
                }
            }
        ]
    }
del a['messaging'][0]['optin']
a['messaging'][0]['hiếu'] = '01' 
print('-'*30)
print(json.dumps(a, indent = 4))
# Out:
# ------------------------------
# {
#     "id": "109523555015462",
#     "time": 1647053291651,
#     "messaging": [
#         {
#             "sender": {
#                 "id": "4857932260991004"
#             },
#             "recipient": {
#                 "id": "109523555015462"
#             },
#             "timestamp": 1647053291403,
#             "hi\u1ebfu": "01"
#         }
#     ]
# }

# %%
dict_ex={ 1: 'January', 2:'Febuary', 3:'March' }
print("Old dictionary-",dict_ex)
dict_ex[2.2] = dict_ex.pop(2)
print("New dictionary-",dict_ex)
# Out:
# Old dictionary- {1: 'January', 2: 'Febuary', 3: 'March'}
# New dictionary- {1: 'January', 3: 'March', 2.2: 'Febuary'}

# %%
import pandas as pd
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
a = """
Bảng tiền lương của tháng {0} năm {1}:
""".format(1,2022) + """   Tên: Hiếu (mã nv)
   Bộ phận: Giám đốc
      + Thu nhập: 123123
      + Ứng trước: 123123
      + Còn lại: 12312321
"""
for i in range(len(d)):
    print(d["col2"][i])
print(a)
# Out:
# 3
# 4
#
# Bảng tiền lương của tháng 1 năm 2022:
#    Tên: Hiếu (mã nv)
#    Bộ phận: Giám đốc
#       + Thu nhập: 123123
#       + Ứng trước: 123123
#       + Còn lại: 12312321

# %%
import pandas as pd
df = pd.DataFrame(columns=['id_fb','check_send'])
for i in range(5):
    df = df.append({'id_fb': i, 'check_send':i}, ignore_index=True)
print(df)
# Out:
#   id_fb check_send
# 0     0          0
# 1     1          1
# 2     2          2
# 3     3          3
# 4     4          4

# %%
import requests
import json
import pandas as pd
InputDataSet = {
    'stt_l': [5, 1, 2], 
    'ma_nv': [1, 4, 5], 
    'id_fb': ['4857932260991004', '4857932260991004', '4857932260991004'], 
    'ten_nv': ['Trần Đình Hiếu', 'Trần Đình Yến', 'Trần Đình Vũ'], 
    'ten_bp': ['Chủ tịch', 'Chủ tịch', 'Chủ tịch'], 
    'thu_nhap': [791676587, 291676587, 916765874],
    'tinh_tru': [202262451, 302262451, 102262451],
    'con_lai': [514503432, 123514503, 514503423],
    'year_l': [2021, 2022, 2022],
    'month_l': [12, 4, 5],
    'stt_o': [1, 2, 3],
    'send_id': ['4857933212991004', '4857932260991004', '4857932260991004'],
    'token_otn': ['3734985410823306900', '6557556848068744744', '7425011328569098440'],
    'date_mfg': ['2022-03-01', '2022-03-02', '2022-03-03'],
    'date_exp': ['2023-04-01', '2023-03-02', '2023-03-01'],
    'date_exec': [None, '2022-06-04', None],
               }
db = pd.DataFrame(data=InputDataSet)
#---------------------------------------


df_check = pd.DataFrame(columns=['token_otn','check_send'])

access_token = "EAAdiPQ5GoRsBAINBQ2aXU9EWabUHLoSNr4MJXS0rwd1em9H89kRqvFIRf2Ad2PZBCW6B084YggWRP60ZBp0IMkclebPht4W7xuprnjmX0e7dYQUM0VeH021hZB5Oh7htrTy90sd8ZAQkrr0adQBz6fl2fgvWpg2bzZAkVBQDwbH8OcrWJKh3F"
end_point = f"https://graph.facebook.com/v13.0/me/messages?access_token={access_token}"
   
for i in range(len(db)):
    contents = """
Bảng tiền lương của tháng {0} năm {1}:  
Tên: {2} (mã nv: {3})
Bộ phận: {4}
    + Thu nhập: {5}
    + Ứng trước: {6}
    + Còn lại: {7}
""".format(db["month_l"][i], db["year_l"][i], db["ten_nv"][i], db["ma_nv"][i], db["ten_bp"][i], db["thu_nhap"][i], db["tinh_tru"][i], db["con_lai"][i])
    notice_token = db["token_otn"][i]
    payload = {
                "recipient": {
                    "one_time_notif_token": notice_token
                },
                "message": {
                    "text": contents
                }
              }
    response = requests.post(end_point, data=json.dumps(payload), headers={"content-type": "application/json"}).json()
    if 'error' in response.keys(): check = 'false' 
    else: check = 'true'
    
    df_check = df_check.append({'token_otn': notice_token, 'check_send':check}, ignore_index=True)
    
    #TODO: Nếu update thành công thì cập nhật mã token trạng thái
print(df_check)
# Out:
# /home/dsa-server/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
#              token_otn check_send
# 0  3734985410823306900      false
# 1  6557556848068744744      false
# 2  7425011328569098440      false

# %%
    
response = {'recipient_id': '4857932260991004', 'message_id': 'm_OAxRlMt1CRDsVkf8D9BN0n2zI_O641bhB3KEhNDGS9dAduZH6jc_LZXN3IjLRkN9noXjFRsgXK3u2S_JKfHWQw'}
print(response)
if 'error' in response.keys(): check = 'false' 
else: check = 'true'
print(check)

# %%
import requests
response = requests.get(url = "https://6237d6d9f5f6e28a154f3fa2.mockapi.io/add")
print(response)
# Out:
# <Response [200]>

# %%
import subprocess
import sys

def install(package):
    subprocess.check_call(["ping", "google.com"])
install("requests")

# %%
import requests

response = requests.get(url = "https://6237d6d9f5f6e28a154f3fa2.mockapi.io/add")
print(response)

# %% [markdown]
# ### Zalo - Sending automation salary

# %%
#------> Send message of type TEXT
import requests
import json
access_token = "N6lRSuG86YTHQjXtYGeR8r5Zq72675TmCohT8f136Gf3UwStxL9W4ZmseGMCB2iaFohfChuQH1mM5C8fndKT0qvqlIteNty-GKU-CDHPUWT2GDuTuKbp4L9tzKBY551uUWwNJUeFL1X7FUK-y0qWDaC9WIARDne8Jnp5M-C_Mmfx090XupHHCKKDvJNJ9207O264Dx0bB6Cw3hnFh0mW61uDcap8DYbT6r2MHPfOCa0NFgzZWYSjK3O5g4k1RJnXENQ3MQ5_1tOvUATTdMy3R1b7f5wBTnD894UOHgPH66WUOxuvbLudQpDWXdswH4PwBMF7Lua60WOG7CPKu57oOeWK62a"
end_point = "https://openapi.zalo.me/v2.0/oa/message"
contents = 1
payload = {
              "recipient": {
                "user_id": "8668477534363029464"
              },
              "message": {
                "text": "\u000b\u0000\u0001\u0000\u0000\u0000qBẢNG LƯƠNG CỦA THÁNG 5 NĂM 2022\nTên: Trần Đình Hiếu\nNSinh: 21/08/2000\nChức vụ: Trùm chợ gà\u000b\u0000\u0002\u0000\u0000\u0000\u0000\u000b\u0000\u0003\u0000\u0000\u0000\u0000\u000b\u0000\u0004\u0000\u0000\u0000\u0000\u0006\u0000\u0005\u0000\u0000\u000b\u0000\u0006\u0000\u0000\u0000\u0003rtf\u000b\u0000\u0007\u0000\u0000\u0001�{\"styles\":[{\"start\":0,\"len\":21,\"st\":\"f_18,c_db342e\"},{\"start\":21,\"len\":1,\"st\":\"f_18,b,c_db342e\"},{\"start\":22,\"len\":5,\"st\":\"f_18,c_db342e\"},{\"start\":27,\"len\":4,\"st\":\"f_18,b,c_db342e\"},{\"start\":32,\"len\":19,\"st\":\"lst_1\"},{\"start\":36,\"len\":15,\"st\":\"b\"},{\"start\":52,\"len\":17,\"st\":\"lst_1\"},{\"start\":58,\"len\":11,\"st\":\"b\"},{\"start\":70,\"len\":20,\"st\":\"lst_1\"},{\"start\":78,\"len\":12,\"st\":\"b\"}],\"ver\":0}\u000b\u0000\b\u0000\u0000\u0000\u0000\u0000"
              }
          }
response = requests.post(end_point, data=json.dumps(payload), 
                         headers={"content-type": "application/json", "access_token": access_token}).json()
print(response)
# Out:
# {'error': -201, 'message': 'Missing message params'}

# %%
#------> Send message of type UPLOAD IMAGE
import requests
import json
access_token = "Jx-iMXx0-bv2lgzU4yBxMaAtfraSrF4Q6Exc43JmrX4iZFaL2_B-ToNUgoOcrPXIOi-V3bpapWXgnTrVCSFQ0otywqXpyjO-BT61L0VPlWmMtwvKDF3zCH3Vu5CxnFmxEyseR0Z1fmiltFTkVk3x7rx8vcvUmj4nViZ3GaNHopbZxEf-IC_N25dI-rLMv_4qTVZkFcQOkNqzfwiu5fYbPpECWYC8hOXx9BZUV3o6ooSzWlXJ09VP6G6Lr4qYZiavVfUSVbYWdpLesfjpLgUK3tQGddndjQfzPQYEE5wNj7D5bfiUUAEfQ42OkXPJiBLM0fwYKJkyb3CzcQL9IsbDPJ8ItFXG"
end_point = "https://openapi.zalo.me/v2.0/oa/message?access_token=" + access_token
contents = 1
payload = { 
  "recipient": {
    "user_id": "8668477534363029464"
  },
  "message": {
    "text": "Zalo đạt 100 triệu người dùng",
    "attachment": {
        "type": "template",
        "payload": {
            "template_type": "media",
            "elements": [{
                "media_type": "image",
                "attachment_id": "wESbL53O_shdvIPILC7iR_JpC552r_fjukKg",
#                 "url": "https://interactive-examples.mdn.mozilla.net/media/cc0-images/grapefruit-slice-332-332.jpg"
            }]
        }
    }
  }
}
response = requests.post(end_point, data=json.dumps(payload), headers={"content-type": "application/json"}).json()
print(response)

# %%
#------> Send message of type IMAGE
import requests
import json
access_token = "N6lRSuG86YTHQjXtYGeR8r5Zq72675TmCohT8f136Gf3UwStxL9W4ZmseGMCB2iaFohfChuQH1mM5C8fndKT0qvqlIteNty-GKU-CDHPUWT2GDuTuKbp4L9tzKBY551uUWwNJUeFL1X7FUK-y0qWDaC9WIARDne8Jnp5M-C_Mmfx090XupHHCKKDvJNJ9207O264Dx0bB6Cw3hnFh0mW61uDcap8DYbT6r2MHPfOCa0NFgzZWYSjK3O5g4k1RJnXENQ3MQ5_1tOvUATTdMy3R1b7f5wBTnD894UOHgPH66WUOxuvbLudQpDWXdswH4PwBMF7Lua60WOG7CPKu57oOeWK62a"
end_point = "https://openapi.zalo.me/v2.0/oa/message?access_token=" + access_token
contents = 1
payload = { 
  "recipient": {
    "user_id": "8668477534363029464"
  },
  "message": {
    "text": "Zalo đạt 100 triệu người dùng",
    "attachment": {
        "type": "template",
        "payload": {
            "template_type": "media",
            "elements": [{
                "media_type": "image",
                "attachment_id": "ejIwChsZGZYgqhqnlg5PAwd5goMxiKy_hTMzDBwaMIwlmAiqul8NVBIEy6lpkbiofOY-P_EfMo--WETujRnE9FxKy7BqeGfvwDFpUFYi0dFeq_v--wGEVl61z76nfbXvyDYfTR2eKNobtQ1nvhK2EMSYVIL6o3Zyi4Ce",
#                 "url": "https://interactive-examples.mdn.mozilla.net/media/cc0-images/grapefruit-slice-332-332.jpg"
            }]
        }
    }
  }
}
response = requests.post(end_point, data=json.dumps(payload), headers={"content-type": "application/json"}).json()
print(response)
# Out:
# {'data': {'message_id': '62f26b15e0c5099850d7', 'user_id': '8668477534363029464'}, 'error': 0, 'message': '[Warning] AccessToken should be placed in header'}

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.savefig('img.png', format='png', bbox_inches='tight',dpi = 80)



import requests

from os import path

filename = 'img.png'  # name example
up = {'image':(filename, open(filename, 'rb'), "multipart/form-data")}
#-----------------
#------> Send message of type IMAGE
import requests
import json

access_token = "N6lRSuG86YTHQjXtYGeR8r5Zq72675TmCohT8f136Gf3UwStxL9W4ZmseGMCB2iaFohfChuQH1mM5C8fndKT0qvqlIteNty-GKU-CDHPUWT2GDuTuKbp4L9tzKBY551uUWwNJUeFL1X7FUK-y0qWDaC9WIARDne8Jnp5M-C_Mmfx090XupHHCKKDvJNJ9207O264Dx0bB6Cw3hnFh0mW61uDcap8DYbT6r2MHPfOCa0NFgzZWYSjK3O5g4k1RJnXENQ3MQ5_1tOvUATTdMy3R1b7f5wBTnD894UOHgPH66WUOxuvbLudQpDWXdswH4PwBMF7Lua60WOG7CPKu57oOeWK62a"
end_point = "https://openapi.zalo.me/v2.0/oa/upload/image"
# ---
response = requests.post(url = end_point, files = up, headers={"access_token": access_token}).json()
print(response)


# plt.savefig(f'1.png', format='png', bbox_inches='tight',dpi = 80)
# Out:
# {'image': ('img.png', <_io.BufferedReader name='img.png'>, 'multipart/form-data')}
# {'error': -201, 'message': 'File not exist!'}

# %%
import numpy as np #-> ver: 1.19.5
import six #-> ver: 1.15.0
import matplotlib.pyplot as plt #-> ver: 3.3.4
import pandas as pd #-> ver: 1.3.5

#----CREATE IMAGE
def table(df = None, name_img = None, title = ""):  
    try:
        #----- Set column STT from Index
        df.index = np.arange(1, len(df) + 1)
        df = df.rename_axis('STT').reset_index()

        def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                            header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                            bbox=[0, 0, 1, 1], header_columns=0,
                            ax=None, **kwargs):
            if ax is None:
                size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
                fig, ax = plt.subplots(figsize=size)
                #Title of table
                ax.set_title(title, fontdict={'fontsize':18, 'fontweight':28,'verticalalignment': 'baseline'})
                ax.axis('off')
            ax.axis([0,1,data.shape[0],-1]) ## <---------- Change here
            #---Param: Title table
            mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)
            mpl_table.auto_set_font_size(False)
            mpl_table.set_fontsize(font_size)
            mpl_table.auto_set_column_width(col=list(range(len(df.columns))))

            for k, cell in six.iteritems(mpl_table._cells):
                cell.set_edgecolor(edge_color)
                if k[0] == 0 or k[1] < header_columns:
                    cell.set_text_props(weight='bold', color='w')
                    cell.set_facecolor(header_color)
                else:
                    cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
            return ax

        def set_row_edge_color(ax, row, column, color):
            #--Grid Row in the table
            for x in range(-1, row+1): ax.axhline(x, color=color)
            #--Grib Column in the table
            # for y in range(column+1): ax.axvline(y/column, color=color)
            for y in range(column): ax.axvline(y, color=color)

        ax = render_mpl_table(df, header_columns=0, col_width=2.0)
        set_row_edge_color(ax, df.shape[0], df.shape[1], 'k')
        # Export Styled Table to PNG
        #---File đang đứng ở chatbot_demo
        plt.savefig(name_img, format='png', bbox_inches='tight',dpi = 80)

        return 1
    except:
        return 0
#---
d = {'col1': [1, 2, 3, 4, 5], 'col2': [3, 4, 5, 6, 7]}
#Dữ liệu bảng lương
df = pd.DataFrame(data=d)
#Thông tin bảng lương
title = "Pikachu"
name_img = "img.png"
check = table(df = df, name_img = name_img, title = title)

# %%
#++++++++++++++++++++++++DATA DEMO+++++++
df = {
    'id_user': [1, 1, 1, 1, 2, 2, 2, 2], 
    'name_u': ['TRẦN ĐÌNH HIẾU', 'TRẦN ĐÌNH HIẾU', 'TRẦN ĐÌNH HIẾU' ,'TRẦN ĐÌNH HIẾU', 'TRẦN ĐÌNH HÒA', 'TRẦN ĐÌNH HÒA', 'TRẦN ĐÌNH HÒA' ,'TRẦN ĐÌNH HÒA'], 
    'birth': ['21/08/2000', '21/08/2000', '21/08/2000', '21/08/2000', '21/08/2000', '21/08/2000', '21/08/2000', '21/08/2000'], 
    'position': ['Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ', 'Trùm trung bộ'], 
    'id_zalo' : ['8668477534363029464','8668477534363029464','8668477534363029464','8668477534363029464','8668477534363029464','8668477534363029464','8668477534363029464','8668477534363029464'],
    'id_salary': [1, 1, 1, 1, 2, 2, 2, 2], 
    'month_s': [3, 3, 3, 3, 3, 3, 3, 3],
    'year_s': [2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
    'id_product': [1, 1, 5, 4, 1, 1, 5, 4],
    'name_p': ['Sầu riêng', 'Sầu riêng', 'Dưa háo', 'Chuối gai', 'Sầu riêng', 'Sầu riêng', 'Dưa háo', 'Chuối gai'],
    'date_d': ['2022-03-27', '2022-03-10', '2022-03-07', '2022-03-13', '2022-03-27', '2022-03-10', '2022-03-07', '2022-03-13'],
    'price_p': [50000, 50000, 10000, 20000, 50000, 50000, 10000, 20000],
    'number': [51, 2, 39, 56, 51, 2, 39, 56],
    'charge': [2550000, 100000, 390000, 1120000, 2550000, 100000, 390000, 1120000],
    'advance': [4160000, 4160000, 4160000, 4160000, 4160000, 4160000, 4160000, 4160000],
    'date_exp': [639708, 639708, 639708, 639708, 639708, 639708, 639708, 639708],
    'remaing': [3520292, 3520292, 3520292, 3520292,3520292, 3520292, 3520292, 3520292]
               }
#++++++++++++++++++++++++++++++
df_check = []

#------------------------(NOTE) TẠO BẢNG KẾT QUẢ GỬI CHO NHANH VIÊN 
import numpy as np #-> ver: 1.19.5
import six #-> ver: 1.15.0
import matplotlib.pyplot as plt #-> ver: 3.3.4
import pandas as pd #-> ver: 1.3.5

#----CREATE IMAGE
def table(df = None, name_img = None, title = ""):  
    try:
        #----- Set column STT from Index
        df.index = np.arange(1, len(df) + 1)
        df = df.rename_axis("STT").reset_index()

        def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                            header_color="#40466e", row_colors=["#f1f1f2", "w"], edge_color="w",
                            bbox=[0, 0, 1, 1], header_columns=0,
                            ax=None, **kwargs):
            if ax is None:
                size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
                fig, ax = plt.subplots(figsize=size)
                #Title of table
                ax.set_title(title, fontdict={"fontsize":18, "fontweight":28,"verticalalignment": "baseline"})
                ax.axis("off")
            ax.axis([0,1,data.shape[0],-1]) ## <---------- Change here
            #---Param: Title table
            mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)
            mpl_table.auto_set_font_size(False)
            mpl_table.set_fontsize(font_size)
            mpl_table.auto_set_column_width(col=list(range(len(df.columns))))

            for k, cell in six.iteritems(mpl_table._cells):
                cell.set_edgecolor(edge_color)
                if k[0] == 0 or k[1] < header_columns:
                    cell.set_text_props(weight="bold", color="w")
                    cell.set_facecolor(header_color)
                else:
                    cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
            return ax

        def set_row_edge_color(ax, row, column, color):
            #--Grid Row in the table
            for x in range(-1, row+1): ax.axhline(x, color=color)
            #--Grib Column in the table
            # for y in range(column+1): ax.axvline(y/column, color=color)
            for y in range(column): ax.axvline(y, color=color)

        ax = render_mpl_table(df, header_columns=0, col_width=2.0)
        set_row_edge_color(ax, df.shape[0], df.shape[1], "k")
        # Export Styled Table to PNG
        #---File đang đứng ở chatbot_demo
        
        plt.savefig(name_img, format="png", bbox_inches="tight",dpi = 80)
        plt.show()

        return 1
    except:
        return 0
#-------------------------------------------
#Dữ liệu bảng lương
# user = db[["id_user", "name_u", "birth", "position", "id_zalo", "month_s", "year_s", "advance", "date_exp", "remaing"]].drop_duplicates().reset_index()
# salary = db[["id_salary", "id_user", "id_product", "name_p", "date_d", "price_p", "number", "charge"]]
# salary.rename(index=str,columns={"id_salary":"Mã lương", "id_user":"Mã NV", "id_product":"Mã SP", "name_p":"Tên SP", "date_d":"Ngày làm", "price_p":"Giá SP", "number":"Số lượng", "charge":"Thành tiền"},inplace=True)

check = table(df = df, name_img = '111', title = "Test")

# %%
import os
import glob
html = ""
html += '<h1 style="background-color: brown;">Hieu1</h1>'

with open("index.html", "w") as outputfile:
	outputfile.write(html)


# imgkit.from_file('index.html', 'out.jpg')
# Open file
# os.startfile("index.html")

# %%
import requests

HCTI_API_ENDPOINT = "https://hcti.io/v1/image"
HCTI_API_USER_ID = '85884ef4-6b15-42d9-8351-7b672b9ffbd5'
HCTI_API_KEY = '432096bd-43dd-4c4c-9e77-69e0530154a5'

data = { 'html': "<div class='box'>Hello, world!</div>",
         'css': ".box { color: white; background-color: #0f79b9; padding: 10px; font-family: Roboto }",
         'google_fonts': "Roboto" }

image = requests.post(url = HCTI_API_ENDPOINT, data = data, auth=(HCTI_API_USER_ID, HCTI_API_KEY))

print(image.json()['url'])
# Out:
# https://hcti.io/v1/image/bed062a5-c7be-4d17-8b25-30f904c6b2aa

# %%
import imgkit
config = imgkit.config(wkhtmltoimage='/opt/bin/wkhtmltoimage', xvfb='/opt/bin/xvfb-run')
imgkit.from_file("index.html", 'out.jpg', config=config)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\HieuCali\File of Hieu\Software\Anaconda\envs\envChatBot\lib\site-packages\imgkit\config.py in get_wkhtmltoimage(self)
#      51             try:
# ---> 52                 with open(self.wkhtmltoimage):
#      53                     pass
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/bin/wkhtmltoimage'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14860/2726282468.py in <module>
#       1 import imgkit
#       2 config = imgkit.config(wkhtmltoimage='/opt/bin/wkhtmltoimage')
# ----> 3 imgkit.from_file("index.html", 'out.jpg', config=config)
#
# ...

# %%
df = {
    'name_u': ['Trần Đình Hiếu'], 'gender': ['Anh'], 'position': ['Trùm trung bộ'], 'department': ['Chuyên viên kĩ thuật'],
    'id_l' :  [3131], 'id_nv' :  [3213], 'date_l' :  ['2021-04-04'], 'total' :  [3377],
    't_lc' :  [3459],
    't_lnp' :  [3541],
    't_lnl' :  [3623],
    't_lncd' :  [3705],
    't_lng' :  [3787],
    't_lcd' :  [3869],
    't_lcl' :  [3951],
    't_pvtad' :  [12],
    't_tcldnccn' :  [13],
    't_tl' :  [11],
    't_others' :  [4279],
    't_htdt' :  [4361],
    't_htxx' :  [4443],
    't_htdl' :  [4525],
    't_htno' :  [4607],
    't_pcbskxd' :  [4689],
    't_tagc' :  [4771],
    't_cn' :  [1],
    't_pcnn' :  [2],
    't_lpcdBHXH' :  [5017],
    't_pcbskxdkn' :  [5099],
    't_kpidv' :  [5181],
    't_cc' :  [5263],
    't_nl' :  [5345],
    't_ng' :  [5427],
    't_cl' :  [5509],
    't_mldBHXH' :  [5591],
    't_pctn' :  [5673],
    't_hsPCBS_KXĐ' :  [1.3],
    't_htt' :  ['A'],
    't_hsdv' :  [0],
    't_np' :  [0],
    't_ncd' :  [0],
    't_cd' :  [0],
    'decline' :  [6247],
    'd_tuk1' :  [6329],
    'd_cdp' :  [6411],
    'd_bhxh' :  [6493],
    'd_bhyt' :  [6575],
    'd_bhtn' :  [6657],
    'd_ttncn' :  [6739],
    'd_ttbhsknt' :  [0],
    'd_bt' :  [6903],
    'd_tt' :  [6985],
    'insurance' :  [7067],
    'i_bhxh' :  [7149],
    'i_bhyt' :  [7231],
    'i_bhtn' :  [7313],
    'residual' :  [7395],
}
import pandas as pd
pd.DataFrame(data=df)
from datetime import datetime
a = f"""
    Họ và tên : {df['gender'][0]} {df['name_u'][0]}
    Tháng {datetime.fromisoformat(df['date_l'][0]).month}
"""
print(a)
# Out:
#     Họ và tên : Anh Trần Đình Hiếu
#     Tháng 4

# %%
from html2image import Html2Image #->version: 2.0.1
import pandas as pd
from datetime import datetime

df = {
    "name_u": ["Trần Đình Hiếu"], "gender": ["Anh"], "position": ["Trùm trung bộ"], "department": ["Công nghệ thông tin"], "id_zalo":['8668477534363029464'], 
    "id_l" :  [3131], "id_nv" :  [3213], "date_l" :  ["2021-04-04"], "total" :  [3377],
    "t_lc" :  [3459],
    "t_lnp" :  [3541],
    "t_lnl" :  [3623],
    "t_lncd" :  [3705],
    "t_lng" :  [3787],
    "t_lcd" :  [3869],
    "t_lcl" :  [3951],
    "t_pvtad" :  [12],
    "t_tcldnccn" :  [13],
    "t_tl" :  [11],
    "t_others" :  [4279],
    "t_htdt" :  [4361],
    "t_htxx" :  [4443],
    "t_htdl" :  [4525],
    "t_htno" :  [4607],
    "t_pcbskxd" :  [4689],
    "t_tagc" :  [4771],
    "t_cn" :  [1],
    "t_pcnn" :  [2],
    "t_lpcdBHXH" :  [5017],
    "t_pcbskxdkn" :  [5099],
    "t_kpidv" :  [5181],
    "t_cc" :  [5263],
    "t_nl" :  [5345],
    "t_ng" :  [5427],
    "t_cl" :  [5509],
    "t_mldBHXH" :  [5591],
    "t_pctn" :  [5673],
    "t_hsPCBS_KXĐ" :  [1.3],
    "t_htt" :  ["A"],
    "t_hsdv" :  [0],
    "t_np" :  [0],
    "t_ncd" :  [0],
    "t_cd" :  [0],
    "decline" :  [6247],
    "d_tuk1" :  [6329],
    "d_cdp" :  [6411],
    "d_bhxh" :  [6493],
    "d_bhyt" :  [6575],
    "d_bhtn" :  [6657],
    "d_ttncn" :  [6739],
    "d_ttbhsknt" :  [0],
    "d_bt" :  [6903],
    "d_tt" :  [6985],
    "insurance" :  [7067],
    "i_bhxh" :  [7149],
    "i_bhyt" :  [7231],
    "i_bhtn" :  [7313],
    "residual" :  [7395],
}
df = pd.DataFrame(data=df)
# START SENDING
# db = InputDataSet
df_check = []

for i in range(len(df)):
    hti = Html2Image()
    month = datetime.fromisoformat(str(df["date_l"][0])).month
    year = datetime.fromisoformat(str(df["date_l"][0])).year
    html = f"""
    <div>
        <meta name="viewport" content="width=device-width, initial-scale=1">
            <style>img{{display: block; margin-right: auto; width:29%; height:8%}}</style>
            </head><body><img src="data:image/png;base64,..." alt="image001 (1)" style="max-width:100%;"></body>
    </div>

    <!-- HEADER -->

    <center class="header" >
        <h1>CÔNG TY CỔ PHẦN CẢNG ĐÀ NẴNG </h1> 
        <h1> PHÒNG TỔ CHỨC TIỀN LƯƠNG</h1>
        <i><p style="font-size: 222%; line-height: 1.5;">Kính gửi: {df["gender"][0]} {df["name_u"][0]}</p></i>
        <h1>BẢNG LƯƠNG CHI TIẾT THÁNG {month} NĂM {year}</h1>
    </center>
    <br><br><br>

    <!-- Info employees -->
    <div class="col-wrap">
        <div class="col" style="color:white;">-----------------</div>
        <div class="col">
            <u><h3>Họ và tên:</h3></u>
            <u><h3>Chức danh: </h3></u>
        </div>
    
        <div class="col" id="values">
        <h3>{df["name_u"][0]}</h3>
        <h3>{df["position"][0]}</h3>
        </div>
    
        <div class="col">
            <u><h3>Mã nhân viên:</h3></u>
            <u><h3>Phòng ban:</h3></u>
        </div>

        <div class="col" id="values">
            <h3>{df["id_nv"][0]}</h3>
            <h3>Phòng {df["department"][0]}</h3>
        </div>
        <div class="col" style="color:white;">-----------------</div>
    </div>


    <!-- CONTENT TABLE -->
    <table class = "content" style="width:85%"  cellpadding="9">
        <caption style="caption-side: bottom; font-style: italic; text-align: right;">(Đơn vị tính: đồng)</caption>
        <thead >
            <tr>
                <td>Mức lương đóng BHXH</td> <td>{df["t_mldBHXH"][0]}</td>
                <td>PC nặng nhọc, độc hại</td> <td>{df["t_pcnn"][0]}</td>
            </tr>
            <tr>
                <td>Phụ cấp trách nhiệm</td> <td>{df["t_pctn"][0]}</td>
                <td>Lương và PC đóng BHXH</td> <td>{df["t_lpcdBHXH"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số PCBS KXĐ</td> <td>{df["t_hsPCBS_KXĐ"][0]}</td>
                <td>PCBS KXĐ kiêm nhiệm</td> <td>{df["t_pcbskxdkn"][0]}</td>
            </tr>
            <tr>
                <td>Hạng thành tích</td> <td>{df["t_htt"][0]}</td>
                <td>KPI đơn vị</td> <td>{df["t_kpidv"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số đơn vị</td> <td>{df["t_hsdv"][0]}</td>
                <td>Công chính</td> <td>{df["t_cc"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ phép</td> <td>{df["t_np"][0]}</td>
                <td>Nghỉ lễ, tết</td> <td>{df["t_nl"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ chế độ</td> <td>{df["t_ncd"][0]}</td>
                <td>Ngoài giờ</td> <td>{df["t_ng"][0]}</td>
            </tr>
            <tr>
                <td>Ca đêm</td> <td>{df["t_cd"][0]}</td>
                <td>Cách ly</td> <td>{df["t_cl"][0]}</td>
            </tr>
            <!-------TỔNG LƯƠNG VÀ KHOẢN TRỪ----->
            <tr>
                <th style="background-color: #83ccab;">Tổng thu nhập</th>
                <th style="background-color: #83ccab;">{df["total"][0]}</th>
                <th style="background-color: #f2b69b;">Các khoản giảm trừ</th>
                <th style="background-color: #f2b69b;">{df["decline"][0]}</th>
            </tr>
            <!------------>
            <tr>
                <td><b>Lương</b></td> <td></td>
                <td>Tạm ứng kỳ 1</td> <td>{df["d_tuk1"][0]} </td>
            </tr>
            <tr>
                <td>Lương chính</td> <td>{df["t_lc"][0]}</td>
                <td>Công đoàn phí</td> <td>{df["d_cdp"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ phép</td> <td>{df["t_lnp"][0]}</td>
                <td>Bảo hiểm xã hội (8%)</td> <td>{df["d_bhxh"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ lễ, tết</td> <td>{df["t_lnl"][0]}</td>
                <td>Bảo hiểm y tế (1,5%)</td> <td>{df["d_bhyt"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ chế độ</td> <td>{df["t_lncd"][0]}</td>
                <td>Bảo hiểm thất nghiệp (1%)</td> <td>{df["d_bhtn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ngoài giờ</td> <td>{df["t_lng"][0]}</td>
                <td>Thuế thu nhập cá nhân</td> <td>{df["d_ttncn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ca đêm</td> <td>{df["t_lcd"][0]}</td>
                <td>Thu tiền BHSK người thân</td> <td>{df["d_ttbhsknt"][0]}</td>
            </tr>
            <tr>
                <td>Lương cách ly</td> <td>{df["t_lcl"][0]}</td>
                <td>Bồi thường</td> <td>{df["d_bt"][0]}</td>
            </tr>
            <tr>
                <td>Phục vụ tàu Ấn Độ</td> <td>{df["t_pvtad"][0]}</td>
                <td>Truy thu</td> <td>{df["d_tt"][0]}</td>
            </tr>
            <tr>
                <td>TC LĐ nữ có con nhỏ</td> <td>{df["t_tcldnccn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Truy lĩnh</td> <td>{df["t_tl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Khác (Họp)</td> <td>{df["t_others"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td><b>Hỗ trợ & bổ sung không xác định</b></td> <td></td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Điện thoại</td> <td>{df["t_htdt"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Xăng xe</td> <td>{df["t_htxx"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Đi lại</td> <td>{df["t_htdl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Nhà ở</td> <td>{df["t_htno"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>PCBS không xác định</td> <td>{df["t_pcbskxd"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Tiền ăn giữa ca</td> <td>{df["t_tagc"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Chống nóng</td> <td>{df["t_cn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"><b>Còn lại thực nhận</b></td>
                <td style="background-color: #edb528;"><b>{df["residual"][0]}</b></td>
            </tr>

            
        </thead>

        
        <tfoot>
            <tr>
                <!-- <th colspan="2">Thành tiền đơn hàng</th>
                <th colspan="2">{df["total"][0]}</th> -->
            </tr>
            <tr>
                <th colspan="2" style="text-align: center;">Tổng mức bảo hiểm Công ty đóng cho NLĐ</th>
                <th colspan="2">{df["insurance"][0]}</th>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm xã hội (17,5%)</td>
                <td colspan="2">{df["i_bhxh"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm y tế (3%)</td>
                <td colspan="2">{df["i_bhyt"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm thất nghiệp (1%)</td>
                <td colspan="2">{df["i_bhtn"][0]}</td>
            </tr>
        </tfoot>
        
    </table>

    <!-- Information contact -->
    <div class="end" >
        <p style="line-height: 1.7; font-size: 120%; margin-left: 80px;"> 
            Chân thành cảm ơn sự đóng góp của {df["gender"][0]} {df["name_u"][0]} ! 
            <br>Mong Anh luôn giữ gìn sức khỏe để gặt hái thêm nhiều thành công tại Công ty. 
            <br>Mọi ý kiến phản hồi vui lòng liên hệ trực tiếp trong hộp thư này, hoặc theo số điện thoại dưới đây. 
            <br><b>Trân trọng.</b>
            <br>Phòng Tổ chức – Tiền lương | Công ty Cổ phần Cảng Đà Nẵng.
            <br>SĐT: 0236 3 822 508 hoặc 0977 545 747 (gặp Trần Thị Quý Thanh).
        </p> 
    </div>
    """
    css = """
    u {
        color:#2d2e2e;
        text-decoration: none;
    }
    #values{
        text-transform: uppercase;
    }
    .header {
        line-height: 0.9;
        font-size: 90%;
        
    }
    .col-wrap {
    display: table;
    width: 100%;
    }

    .col {
    display: table-cell;
    padding: 1rem
    }
    /* ----------------------- */
    /* Cấu trúc bảng */
    .content{
        width: 100%;
        border:2px solid black;border-collapse:collapse;
        margin-left:auto;
        margin-right:auto;
        font-size: 110%;

    }

    td, th {
        border:1px solid black;border-collapse:collapse;
        height: 40px;
    }

    /* Cột không in đậm */
    td:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
        width: 35%;
    } 
    td:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    } 
    /* Cột in đậm */
    th:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
    } 
    th:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    }
    """
    name_img = f"salary_{i}.png"
    hti.screenshot(html_str=html, css_str=css, save_as = name_img, size=(1350,2222))
    #-----------------UPLOAD IMAGE TO SERVER ZALO
    import requests
    import json
    url = "https://openapi.zalo.me/v2.0/oa/upload/image"
    files = [
        ("file",("file",open(name_img,"rb"),"multipart/form-data"))
    ]
    access_token = "TZTpOTD3Pd1xDd1bta5dT7i_U6BHLmSFALWCGVfxKWS-2Z51roPcItWF546KFtuYFXejSDKFQGqiVY1frMyrFNv78pUBPsX5P7KU8wv1MIbSR0n0y6vC2YX247pgO6Pk6sbtCyXdCqjXMLuvj5CQNKPaPWYF5IfC82Tv4v1O2dzXRM0PjbiWRr9sJpwkSGjiN4Dw1Orj1KnuNta1h4vlRtTT3Hs1Q7ngSHmO9veGH49IOoWhjKHxQtTd90cTS7T2U7aPLhLPKYvRK2r-dbvV4ZH93b_EFK5E118o0yPdTKmZIm8n_Mb0S59T107_U19nBNLu5TrKBLWVI4HFdKOc9zzVP7u"
    headers = { "access_token": access_token }
    response = requests.request("POST", url, headers = headers, files=files)
    
    #---------------SEND IMAGE TO USER
    if response.ok:
        end_point = "https://openapi.zalo.me/v2.0/oa/message"
        user_id = df["id_zalo"][i]
        text = f"""BẢNG LƯƠNG CHI TIẾT THÁNG {month} NĂM {year} - {df["gender"][0]} {df["name_u"][0]} (Mã: {df["id_nv"][0]})"""
        payload = { 
            "recipient": {
            "user_id": user_id
            },
            "message": {
            "text": text,
            "attachment": {
                "type": "template",
                "payload": {
                    "template_type": "media",
                    "elements": [{
                        "media_type": "image",
                        "attachment_id": response.json()["data"].get("attachment_id"),
        #                 "url": "https://interactive-examples.mdn.mozilla.net/media/cc0-images/grapefruit-slice-332-332.jpg"
                    }]
                }
            }
            }
        }
        response = requests.post(end_point, data=json.dumps(payload), headers = headers)
        if response.ok:
            status = "send success"
        else: 
            status = "send failed"
    else: 
        status = "create image failed"   
    time = datetime.now()
    df_check.append({"id_send":i, "id_zalo": df["id_zalo"][i], "id_salary": df["id_l"][0], "time_send": time, "status": status})
OutputDataSet = pd.DataFrame.from_dict(df_check, orient="columns")
print(OutputDataSet)
# Out:
#    id_send              id_zalo  id_salary                  time_send  \
# 0        0  8668477534363029464       3131 2022-04-14 15:37:55.723390
#
#          status
# 0  send success

# %%
from os import walk

filenames = next(walk("./"), (None, None, []))[2]
print(filenames)
# Out:
# ['error.txt', 'facebook_main.py', 'Figure_1.png', 'img.png', 'index.html', 'index.png', 'Jupyter-Draft.ipynb', 'log-action.log', 'ngrok.exe', 'red_page.png', 'run_window.sh', 'salary.html', 'salary_0.png', 'salary_0.png3', 'salary_2.png', 'sale.xlsx', 'setup.sh', 'Untitled.ipynb', 'Window-Step to run Server.txt']

# %%
from html2image import Html2Image #->version: 2.0.1
import pandas as pd
from datetime import datetime

df = {
    "name_u": ["Trần Đình Hiếu"], "gender": ["Anh"], "position": ["Trùm trung bộ"], "department": ["Công nghệ thông tin"], "id_zalo":['8668477534363029464'], 
    "id_l" :  [3131], "id_nv" :  [3213], "date_l" :  ["2021-04-04"], "total" :  [3377],
    "t_lc" :  [3459],
    "t_lnp" :  [3541],
    "t_lnl" :  [3623],
    "t_lncd" :  [3705],
    "t_lng" :  [3787],
    "t_lcd" :  [3869],
    "t_lcl" :  [3951],
    "t_pvtad" :  [12],
    "t_tcldnccn" :  [13],
    "t_tl" :  [11],
    "t_others" :  [4279],
    "t_htdt" :  [4361],
    "t_htxx" :  [4443],
    "t_htdl" :  [4525],
    "t_htno" :  [4607],
    "t_pcbskxd" :  [4689],
    "t_tagc" :  [4771],
    "t_cn" :  [1],
    "t_pcnn" :  [2],
    "t_lpcdBHXH" :  [5017],
    "t_pcbskxdkn" :  [5099],
    "t_kpidv" :  [5181],
    "t_cc" :  [5263],
    "t_nl" :  [5345],
    "t_ng" :  [5427],
    "t_cl" :  [5509],
    "t_mldBHXH" :  [5591],
    "t_pctn" :  [5673],
    "t_hsPCBS_KXĐ" :  [1.3],
    "t_htt" :  ["A"],
    "t_hsdv" :  [0],
    "t_np" :  [0],
    "t_ncd" :  [0],
    "t_cd" :  [0],
    "decline" :  [6247],
    "d_tuk1" :  [6329],
    "d_cdp" :  [6411],
    "d_bhxh" :  [6493],
    "d_bhyt" :  [6575],
    "d_bhtn" :  [6657],
    "d_ttncn" :  [6739],
    "d_ttbhsknt" :  [0],
    "d_bt" :  [6903],
    "d_tt" :  [6985],
    "insurance" :  [7067],
    "i_bhxh" :  [7149],
    "i_bhyt" :  [7231],
    "i_bhtn" :  [7313],
    "residual" :  [7395],
}
df = pd.DataFrame(data=df)
# START SENDING
# db = InputDataSet
df_check = []

for i in range(len(df)):
    hti = Html2Image()
    month = datetime.fromisoformat(str(df["date_l"][0])).month
    year = datetime.fromisoformat(str(df["date_l"][0])).year
    html = f"""
    <div>
        <meta name="viewport" content="width=device-width, initial-scale=1">
            <style>img{{display: block; margin-right: auto; width:29%; height:8%}}</style>
            </head><body><img src="data:image/png;base64,..." alt="image001 (1)" style="max-width:100%;"></body>
    </div>

    <!-- HEADER -->

    <center class="header" >
        <h1>CÔNG TY CỔ PHẦN CẢNG ĐÀ NẴNG </h1> 
        <h1> PHÒNG TỔ CHỨC TIỀN LƯƠNG</h1>
        <i><p style="font-size: 222%; line-height: 1.5;">Kính gửi: {df["gender"][0]} {df["name_u"][0]}</p></i>
        <h1>BẢNG LƯƠNG CHI TIẾT THÁNG {month} NĂM {year}</h1>
    </center>
    <br><br><br>

    <!-- Info employees -->
    <div class="col-wrap">
        <div class="col" style="color:white;">-----------------</div>
        <div class="col">
            <u><h3>Họ và tên:</h3></u>
            <u><h3>Chức danh: </h3></u>
        </div>
    
        <div class="col" id="values">
        <h3>{df["name_u"][0]}</h3>
        <h3>{df["position"][0]}</h3>
        </div>
    
        <div class="col">
            <u><h3>Mã nhân viên:</h3></u>
            <u><h3>Phòng ban:</h3></u>
        </div>

        <div class="col" id="values">
            <h3>{df["id_nv"][0]}</h3>
            <h3>Phòng {df["department"][0]}</h3>
        </div>
        <div class="col" style="color:white;">-----------------</div>
    </div>


    <!-- CONTENT TABLE -->
    <table class = "content" style="width:85%"  cellpadding="9">
        <caption style="caption-side: bottom; font-style: italic; text-align: right;">(Đơn vị tính: đồng)</caption>
        <thead >
            <tr>
                <td>Mức lương đóng BHXH</td> <td>{df["t_mldBHXH"][0]}</td>
                <td>PC nặng nhọc, độc hại</td> <td>{df["t_pcnn"][0]}</td>
            </tr>
            <tr>
                <td>Phụ cấp trách nhiệm</td> <td>{df["t_pctn"][0]}</td>
                <td>Lương và PC đóng BHXH</td> <td>{df["t_lpcdBHXH"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số PCBS KXĐ</td> <td>{df["t_hsPCBS_KXĐ"][0]}</td>
                <td>PCBS KXĐ kiêm nhiệm</td> <td>{df["t_pcbskxdkn"][0]}</td>
            </tr>
            <tr>
                <td>Hạng thành tích</td> <td>{df["t_htt"][0]}</td>
                <td>KPI đơn vị</td> <td>{df["t_kpidv"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số đơn vị</td> <td>{df["t_hsdv"][0]}</td>
                <td>Công chính</td> <td>{df["t_cc"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ phép</td> <td>{df["t_np"][0]}</td>
                <td>Nghỉ lễ, tết</td> <td>{df["t_nl"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ chế độ</td> <td>{df["t_ncd"][0]}</td>
                <td>Ngoài giờ</td> <td>{df["t_ng"][0]}</td>
            </tr>
            <tr>
                <td>Ca đêm</td> <td>{df["t_cd"][0]}</td>
                <td>Cách ly</td> <td>{df["t_cl"][0]}</td>
            </tr>
            <!-------TỔNG LƯƠNG VÀ KHOẢN TRỪ----->
            <tr>
                <th style="background-color: #83ccab;">Tổng thu nhập</th>
                <th style="background-color: #83ccab;">{df["total"][0]}</th>
                <th style="background-color: #f2b69b;">Các khoản giảm trừ</th>
                <th style="background-color: #f2b69b;">{df["decline"][0]}</th>
            </tr>
            <!------------>
            <tr>
                <td><b>Lương</b></td> <td></td>
                <td>Tạm ứng kỳ 1</td> <td>{df["d_tuk1"][0]} </td>
            </tr>
            <tr>
                <td>Lương chính</td> <td>{df["t_lc"][0]}</td>
                <td>Công đoàn phí</td> <td>{df["d_cdp"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ phép</td> <td>{df["t_lnp"][0]}</td>
                <td>Bảo hiểm xã hội (8%)</td> <td>{df["d_bhxh"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ lễ, tết</td> <td>{df["t_lnl"][0]}</td>
                <td>Bảo hiểm y tế (1,5%)</td> <td>{df["d_bhyt"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ chế độ</td> <td>{df["t_lncd"][0]}</td>
                <td>Bảo hiểm thất nghiệp (1%)</td> <td>{df["d_bhtn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ngoài giờ</td> <td>{df["t_lng"][0]}</td>
                <td>Thuế thu nhập cá nhân</td> <td>{df["d_ttncn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ca đêm</td> <td>{df["t_lcd"][0]}</td>
                <td>Thu tiền BHSK người thân</td> <td>{df["d_ttbhsknt"][0]}</td>
            </tr>
            <tr>
                <td>Lương cách ly</td> <td>{df["t_lcl"][0]}</td>
                <td>Bồi thường</td> <td>{df["d_bt"][0]}</td>
            </tr>
            <tr>
                <td>Phục vụ tàu Ấn Độ</td> <td>{df["t_pvtad"][0]}</td>
                <td>Truy thu</td> <td>{df["d_tt"][0]}</td>
            </tr>
            <tr>
                <td>TC LĐ nữ có con nhỏ</td> <td>{df["t_tcldnccn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Truy lĩnh</td> <td>{df["t_tl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Khác (Họp)</td> <td>{df["t_others"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td><b>Hỗ trợ & bổ sung không xác định</b></td> <td></td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Điện thoại</td> <td>{df["t_htdt"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Xăng xe</td> <td>{df["t_htxx"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Đi lại</td> <td>{df["t_htdl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Nhà ở</td> <td>{df["t_htno"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>PCBS không xác định</td> <td>{df["t_pcbskxd"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Tiền ăn giữa ca</td> <td>{df["t_tagc"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Chống nóng</td> <td>{df["t_cn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"><b>Còn lại thực nhận</b></td>
                <td style="background-color: #edb528;"><b>{df["residual"][0]}</b></td>
            </tr>

            
        </thead>

        
        <tfoot>
            <tr>
                <!-- <th colspan="2">Thành tiền đơn hàng</th>
                <th colspan="2">{df["total"][0]}</th> -->
            </tr>
            <tr>
                <th colspan="2" style="text-align: center;">Tổng mức bảo hiểm Công ty đóng cho NLĐ</th>
                <th colspan="2">{df["insurance"][0]}</th>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm xã hội (17,5%)</td>
                <td colspan="2">{df["i_bhxh"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm y tế (3%)</td>
                <td colspan="2">{df["i_bhyt"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm thất nghiệp (1%)</td>
                <td colspan="2">{df["i_bhtn"][0]}</td>
            </tr>
        </tfoot>
        
    </table>

    <!-- Information contact -->
    <div class="end" >
        <p style="line-height: 1.7; font-size: 120%; margin-left: 80px;"> 
            Chân thành cảm ơn sự đóng góp của {df["gender"][0]} {df["name_u"][0]} ! 
            <br>Mong Anh luôn giữ gìn sức khỏe để gặt hái thêm nhiều thành công tại Công ty. 
            <br>Mọi ý kiến phản hồi vui lòng liên hệ trực tiếp trong hộp thư này, hoặc theo số điện thoại dưới đây. 
            <br><b>Trân trọng.</b>
            <br>Phòng Tổ chức – Tiền lương | Công ty Cổ phần Cảng Đà Nẵng.
            <br>SĐT: 0236 3 822 508 hoặc 0977 545 747 (gặp Trần Thị Quý Thanh).
        </p> 
    </div>
    """
    css = """
    u {
        color:#2d2e2e;
        text-decoration: none;
    }
    #values{
        text-transform: uppercase;
    }
    .header {
        line-height: 0.9;
        font-size: 90%;
        
    }
    .col-wrap {
    display: table;
    width: 100%;
    }

    .col {
    display: table-cell;
    padding: 1rem
    }
    /* ----------------------- */
    /* Cấu trúc bảng */
    .content{
        width: 100%;
        border:2px solid black;border-collapse:collapse;
        margin-left:auto;
        margin-right:auto;
        font-size: 110%;

    }

    td, th {
        border:1px solid black;border-collapse:collapse;
        height: 40px;
    }

    /* Cột không in đậm */
    td:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
        width: 35%;
    } 
    td:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    } 
    /* Cột in đậm */
    th:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
    } 
    th:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    }
    """
    name_img = f"salary_{i}.png"
    hti.screenshot(html_str=html, css_str=css, save_as = name_img, size=(1350,2222))
    #-----------------UPLOAD IMAGE TO SERVER ZALO
    import requests
    import json
    url = "https://openapi.zalo.me/v2.0/oa/upload/image"
    files = [
        ("file",("file",open(name_img,"rb"),"multipart/form-data"))
    ]
    access_token = "TZTpOTD3Pd1xDd1bta5dT7i_U6BHLmSFALWCGVfxKWS-2Z51roPcItWF546KFtuYFXejSDKFQGqiVY1frMyrFNv78pUBPsX5P7KU8wv1MIbSR0n0y6vC2YX247pgO6Pk6sbtCyXdCqjXMLuvj5CQNKPaPWYF5IfC82Tv4v1O2dzXRM0PjbiWRr9sJpwkSGjiN4Dw1Orj1KnuNta1h4vlRtTT3Hs1Q7ngSHmO9veGH49IOoWhjKHxQtTd90cTS7T2U7aPLhLPKYvRK2r-dbvV4ZH93b_EFK5E118o0yPdTKmZIm8n_Mb0S59T107_U19nBNLu5TrKBLWVI4HFdKOc9zzVP7u"
    headers = { "access_token": access_token }
    response = requests.request("POST", url, headers = headers, files=files)
    
    #---------------SEND IMAGE TO USER
    if response.ok:
        end_point = "https://openapi.zalo.me/v2.0/oa/message"
        user_id = df["id_zalo"][i]
        text = f"""BẢNG LƯƠNG CHI TIẾT THÁNG {month} NĂM {year} - {df["gender"][0]} {df["name_u"][0]} (Mã: {df["id_nv"][0]})"""
        payload = { 
            "recipient": {
            "user_id": user_id
            },
            "message": {
            "text": text,
            "attachment": {
                "type": "template",
                "payload": {
                    "template_type": "media",
                    "elements": [{
                        "media_type": "image",
                        "attachment_id": response.json()["data"].get("attachment_id"),
        #                 "url": "https://interactive-examples.mdn.mozilla.net/media/cc0-images/grapefruit-slice-332-332.jpg"
                    }]
                }
            }
            }
        }
        response = requests.post(end_point, data=json.dumps(payload), headers = headers)
        if response.ok:
            status = "send success"
        else: 
            status = "send failed"
    else: 
        status = "create image failed"   
    time = datetime.now()
    df_check.append({"id_send":i, "id_zalo": df["id_zalo"][i], "id_salary": df["id_l"][0], "time_send": time, "status": status})
OutputDataSet = pd.DataFrame.from_dict(df_check, orient="columns")
print(OutputDataSet)
# Out:
#            name_u gender       position            department  id_l  id_nv  \
# 0  Trần Đình Hiếu    Anh  Trùm trung bộ  Chuyên viên kĩ thuật  3131   3213
#
#        date_l  total  t_lc  t_lnp  ...  d_bhtn  d_ttncn  d_ttbhsknt  d_bt  \
# 0  2021-04-04   3377  3459   3541  ...    6657     6739           0  6903
#
#    d_tt  insurance  i_bhxh  i_bhyt  i_bhtn  residual
# 0  6985       7067    7149    7231    7313      7395
#
# [1 rows x 57 columns]

# %%
#------------------------(NOTE) TẠO BẢNG KẾT QUẢ GỬI CHO NHANH VIÊN 

df = {
    "name_u": ["Trần Đình Hiếu"], "gender": ["Anh"], "position": ["Trùm trung bộ"], "department": ["Công nghệ thông tin"], "id_zalo":['8668477534363029464'], 
    "id_l" :  [3131], "id_nv" :  [3213], "date_l" :  ["2021-04-04"], "total" :  [3377],
    "t_lc" :  [3459],
    "t_lnp" :  [3541],
    "t_lnl" :  [3623],
    "t_lncd" :  [3705],
    "t_lng" :  [3787],
    "t_lcd" :  [3869],
    "t_lcl" :  [3951],
    "t_pvtad" :  [12],
    "t_tcldnccn" :  [13],
    "t_tl" :  [11],
    "t_others" :  [4279],
    "t_htdt" :  [4361],
    "t_htxx" :  [4443],
    "t_htdl" :  [4525],
    "t_htno" :  [4607],
    "t_pcbskxd" :  [4689],
    "t_tagc" :  [4771],
    "t_cn" :  [1],
    "t_pcnn" :  [2],
    "t_lpcdBHXH" :  [5017],
    "t_pcbskxdkn" :  [5099],
    "t_kpidv" :  [5181],
    "t_cc" :  [5263],
    "t_nl" :  [5345],
    "t_ng" :  [5427],
    "t_cl" :  [5509],
    "t_mldBHXH" :  [5591],
    "t_pctn" :  [5673],
    "t_hsPCBS_KXĐ" :  [1.3],
    "t_htt" :  ["A"],
    "t_hsdv" :  [0],
    "t_np" :  [0],
    "t_ncd" :  [0],
    "t_cd" :  [0],
    "decline" :  [6247],
    "d_tuk1" :  [6329],
    "d_cdp" :  [6411],
    "d_bhxh" :  [6493],
    "d_bhyt" :  [6575],
    "d_bhtn" :  [6657],
    "d_ttncn" :  [6739],
    "d_ttbhsknt" :  [0],
    "d_bt" :  [6903],
    "d_tt" :  [6985],
    "insurance" :  [7067],
    "i_bhxh" :  [7149],
    "i_bhyt" :  [7231],
    "i_bhtn" :  [7313],
    "residual" :  [7395],
}
df = pd.DataFrame(data=df)
# START SENDING
# db = InputDataSet
df_check = []

import requests
import json
import pandas as pd
from datetime import datetime
HCTI_API_ENDPOINT = "https://hcti.io/v1/image"
HCTI_API_USER_ID = '85884ef4-6b15-42d9-8351-7b672b9ffbd5'
HCTI_API_KEY = '432096bd-43dd-4c4c-9e77-69e0530154a5'


for i in range(len(df)):
    month = datetime.fromisoformat(str(df["date_l"][0])).month
    year = datetime.fromisoformat(df["date_l"][0]).year
    html = f"""
    <div>
        <meta name="viewport" content="width=device-width, initial-scale=1">
            <style>img{{display: block; margin-right: auto; width:29%; height:8%}}</style>
            </head><body><img src="data:image/png;base64,..." alt="image001 (1)" style="max-width:100%;"></body>
    </div>

    <!-- HEADER -->

    <center class="header" >
        <h1>CÔNG TY CỔ PHẦN CẢNG ĐÀ NẴNG </h1> 
        <h1> PHÒNG TỔ CHỨC TIỀN LƯƠNG</h1>
        <i><p style="font-size: 222%; line-height: 1.5;">Kính gửi: {df["gender"][0]} {df["name_u"][0]}</p></i>
        <h1>BẢNG LƯƠNG CHI TIẾT THÁNG {datetime.fromisoformat(df["date_l"][0]).month} NĂM {datetime.fromisoformat(df["date_l"][0]).year}</h1>
    </center>
    <br><br><br>

    <!-- Info employees -->
    <div class="col-wrap">
        <div class="col" style="color:white;">-----------------</div>
        <div class="col">
            <u><h3>Họ và tên:</h3></u>
            <u><h3>Chức danh: </h3></u>
        </div>
    
        <div class="col" id="values">
        <h3>{df["name_u"][0]}</h3>
        <h3>{df["position"][0]}</h3>
        </div>
    
        <div class="col">
            <u><h3>Mã nhân viên:</h3></u>
            <u><h3>Phòng ban:</h3></u>
        </div>

        <div class="col" id="values">
            <h3>{df["id_nv"][0]}</h3>
            <h3>Phòng {df["department"][0]}</h3>
        </div>
        <div class="col" style="color:white;">-----------------</div>
    </div>


    <!-- CONTENT TABLE -->
    <table class = "content" style="width:85%"  cellpadding="9">
        <caption style="caption-side: bottom; font-style: italic; text-align: right;">(Đơn vị tính: đồng)</caption>
        <thead >
            <tr>
                <td>Mức lương đóng BHXH</td> <td>{df["t_mldBHXH"][0]}</td>
                <td>PC nặng nhọc, độc hại</td> <td>{df["t_pcnn"][0]}</td>
            </tr>
            <tr>
                <td>Phụ cấp trách nhiệm</td> <td>{df["t_pctn"][0]}</td>
                <td>Lương và PC đóng BHXH</td> <td>{df["t_lpcdBHXH"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số PCBS KXĐ</td> <td>{df["t_hsPCBS_KXĐ"][0]}</td>
                <td>PCBS KXĐ kiêm nhiệm</td> <td>{df["t_pcbskxdkn"][0]}</td>
            </tr>
            <tr>
                <td>Hạng thành tích</td> <td>{df["t_htt"][0]}</td>
                <td>KPI đơn vị</td> <td>{df["t_kpidv"][0]}</td>
            </tr>
            <tr>
                <td>Hệ số đơn vị</td> <td>{df["t_hsdv"][0]}</td>
                <td>Công chính</td> <td>{df["t_cc"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ phép</td> <td>{df["t_np"][0]}</td>
                <td>Nghỉ lễ, tết</td> <td>{df["t_nl"][0]}</td>
            </tr>
            <tr>
                <td>Nghỉ chế độ</td> <td>{df["t_ncd"][0]}</td>
                <td>Ngoài giờ</td> <td>{df["t_ng"][0]}</td>
            </tr>
            <tr>
                <td>Ca đêm</td> <td>{df["t_cd"][0]}</td>
                <td>Cách ly</td> <td>{df["t_cl"][0]}</td>
            </tr>
            <!-------TỔNG LƯƠNG VÀ KHOẢN TRỪ----->
            <tr>
                <th style="background-color: #83ccab;">Tổng thu nhập</th>
                <th style="background-color: #83ccab;">{df["total"][0]}</th>
                <th style="background-color: #f2b69b;">Các khoản giảm trừ</th>
                <th style="background-color: #f2b69b;">{df["decline"][0]}</th>
            </tr>
            <!------------>
            <tr>
                <td><b>Lương</b></td> <td></td>
                <td>Tạm ứng kỳ 1</td> <td>{df["d_tuk1"][0]} </td>
            </tr>
            <tr>
                <td>Lương chính</td> <td>{df["t_lc"][0]}</td>
                <td>Công đoàn phí</td> <td>{df["d_cdp"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ phép</td> <td>{df["t_lnp"][0]}</td>
                <td>Bảo hiểm xã hội (8%)</td> <td>{df["d_bhxh"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ lễ, tết</td> <td>{df["t_lnl"][0]}</td>
                <td>Bảo hiểm y tế (1,5%)</td> <td>{df["d_bhyt"][0]}</td>
            </tr>
            <tr>
                <td>Lương nghỉ chế độ</td> <td>{df["t_lncd"][0]}</td>
                <td>Bảo hiểm thất nghiệp (1%)</td> <td>{df["d_bhtn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ngoài giờ</td> <td>{df["t_lng"][0]}</td>
                <td>Thuế thu nhập cá nhân</td> <td>{df["d_ttncn"][0]}</td>
            </tr>
            <tr>
                <td>Lương ca đêm</td> <td>{df["t_lcd"][0]}</td>
                <td>Thu tiền BHSK người thân</td> <td>{df["d_ttbhsknt"][0]}</td>
            </tr>
            <tr>
                <td>Lương cách ly</td> <td>{df["t_lcl"][0]}</td>
                <td>Bồi thường</td> <td>{df["d_bt"][0]}</td>
            </tr>
            <tr>
                <td>Phục vụ tàu Ấn Độ</td> <td>{df["t_pvtad"][0]}</td>
                <td>Truy thu</td> <td>{df["d_tt"][0]}</td>
            </tr>
            <tr>
                <td>TC LĐ nữ có con nhỏ</td> <td>{df["t_tcldnccn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Truy lĩnh</td> <td>{df["t_tl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Khác (Họp)</td> <td>{df["t_others"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td><b>Hỗ trợ & bổ sung không xác định</b></td> <td></td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Điện thoại</td> <td>{df["t_htdt"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Xăng xe</td> <td>{df["t_htxx"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Đi lại</td> <td>{df["t_htdl"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Hỗ trợ Nhà ở</td> <td>{df["t_htno"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>PCBS không xác định</td> <td>{df["t_pcbskxd"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Tiền ăn giữa ca</td> <td>{df["t_tagc"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td>Chống nóng</td> <td>{df["t_cn"][0]}</td>
                <td></td> <td></td>
            </tr>
            <tr>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"></td>
                <td style="background-color: #edb528;"><b>Còn lại thực nhận</b></td>
                <td style="background-color: #edb528;"><b>{df["residual"][0]}</b></td>
            </tr>

            
        </thead>

        
        <tfoot>
            <tr>
                <!-- <th colspan="2">Thành tiền đơn hàng</th>
                <th colspan="2">{df["total"][0]}</th> -->
            </tr>
            <tr>
                <th colspan="2" style="text-align: center;">Tổng mức bảo hiểm Công ty đóng cho NLĐ</th>
                <th colspan="2">{df["insurance"][0]}</th>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm xã hội (17,5%)</td>
                <td colspan="2">{df["i_bhxh"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm y tế (3%)</td>
                <td colspan="2">{df["i_bhyt"][0]}</td>
            </tr>
            <tr>
                <td colspan="2">Bảo hiểm thất nghiệp (1%)</td>
                <td colspan="2">{df["i_bhtn"][0]}</td>
            </tr>
        </tfoot>
        
    </table>

    <!-- Information contact -->
    <div class="end" >
        <p style="line-height: 1.7; font-size: 120%; margin-left: 80px;"> 
            Chân thành cảm ơn sự đóng góp của {df["gender"][0]} {df["name_u"][0]} ! 
            <br>Mong Anh luôn giữ gìn sức khỏe để gặt hái thêm nhiều thành công tại Công ty. 
            <br>Mọi ý kiến phản hồi vui lòng liên hệ trực tiếp trong hộp thư này, hoặc theo số điện thoại dưới đây. 
            <br><b>Trân trọng.</b>
            <br>Phòng Tổ chức – Tiền lương | Công ty Cổ phần Cảng Đà Nẵng.
            <br>SĐT: 0236 3 822 508 hoặc 0977 545 747 (gặp Trần Thị Quý Thanh).
        </p> 
    </div>
    """
    css = """
    body, html {
        height: 100%;
        width: 150%;
    }
    u {
        color:#2d2e2e;
        text-decoration: none;
    }
    #values{
        text-transform: uppercase;
    }
    .header {
        line-height: 0.9;
        font-size: 90%;
        
    }
    .col-wrap {
    display: table;
    width: 100%;
    }

    .col {
    display: table-cell;
    padding: 1rem
    }
    /* ----------------------- */
    /* Cấu trúc bảng */
    .content{
        width: 100%;
        border:2px solid black;border-collapse:collapse;
        margin-left:auto;
        margin-right:auto;
        font-size: 110%;

    }

    td, th {
        border:1px solid black;border-collapse:collapse;
        height: 40px;
    }

    /* Cột không in đậm */
    td:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
        width: 35%;
    } 
    td:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    } 
    /* Cột in đậm */
    th:nth-child(odd) {  
        background-color: #fff;  
        text-align: left;
        padding-left: 2.5%;
    } 
    th:nth-child(even) {  
        /* background-color: rgb(161, 56, 56); */
        text-align: right;  
        padding-right: 2.5%;
    }
    """

    data = { 'html': html,
         'css': css,
         'google_fonts': "Roboto" }

    #image = requests.post(url = HCTI_API_ENDPOINT, data = data, auth=(HCTI_API_USER_ID, HCTI_API_KEY)).json()['url']
    #print(image)
    #SEND IMAGE
    access_token = "9eyCMLLb61ehZWzTM6SP7Yk71rfNSKD4CSOUSavmI4bCunSHSs5255lzB3veJ74FVCqJ4W92R38d_YKk7L11RZ7h56euLLr5F-esM2vgKcWmrKGf4NeF9WdaKH9oOpqKIV1i9aXI83vf-4qFMcfTAIVeInSuIGLFCEjQQmf2DrKfzc4IFLyS5oBB0ZquG7KBHDzbEKnEC3jKsMyfVb8CBrQdH6bn60vMNwfc6oCw3XStiXqX5I5DBWJC0prYTM4HJkeI03DqMISyv3SGEqvN327o6GqzHrWp0FGS52HfUYa-_XWBHXzS6N-hFGeC9rqwTvnAFMGEMmnQu0XCRKlO9tLPUHeK"
    headers = { "access_token": access_token }
    #---------------SEND IMAGE TO USER
    end_point = "https://openapi.zalo.me/v2.0/oa/message"
    user_id = df["id_zalo"][i]
    text = f"""BẢNG LƯƠNG CHI TIẾT THÁNG {datetime.fromisoformat(df["date_l"][0]).month} NĂM {datetime.fromisoformat(df["date_l"][0]).year} - {df["gender"][0]} {df["name_u"][0]} (Mã: {df["id_nv"][0]})"""
    payload = { 
        "recipient": {
        "user_id": user_id
        },
        "message": {
        "text": text,
        "attachment": {
            "type": "template",
            "payload": {
                "template_type": "media",
                "elements": [{
                    "media_type": "image",
                    # "attachment_id": response.json()["data"].get("attachment_id"),
                    "url": "httpss://hcti.io/v1/image/c8303588-3f7f-4442-8b65-d8f849323896"
                }]
            }
        }
        }
    }
    for j in range(3):
        response = requests.post(end_point, data=json.dumps(payload), headers = headers)
        if response.json()["error"] == 0 :
            break
        # if response.status_code 
    print(payload)
    print(response.text)
    if response.ok:
        status = "send success"
    else: 
        status = "send failed" 
    time = datetime.now()
    df_check.append({"id_send":i, "id_zalo": df["id_zalo"][i], "id_salary": df["id_l"][0], "time_send": time, "status": status})
OutputDataSet = pd.DataFrame.from_dict(df_check, orient="columns")
# Out:
# {'recipient': {'user_id': '8668477534363029464'}, 'message': {'text': 'BẢNG LƯƠNG CHI TIẾT THÁNG 4 NĂM 2021 - Anh Trần Đình Hiếu (Mã: 3213)', 'attachment': {'type': 'template', 'payload': {'template_type': 'media', 'elements': [{'media_type': 'image', 'url': 'httpss://hcti.io/v1/image/c8303588-3f7f-4442-8b65-d8f849323896'}]}}}}
# {"error":-201,"message":"url is not valid"}

# %%
print(image)
# Out:
# https://hcti.io/v1/image/c8303588-3f7f-4442-8b65-d8f849323896

# %%
from html2image import Html2Image
hti = Html2Image()
hti.output_path = "C:/Users/dinhh"
print(hti.screenshot(html_str="<h1>hieu</h1>", save_as = "image.jpeg"))
from os import walk
filenames = next(walk("C:/Users/dinhh"), (None, None, []))[2]
print(filenames)
# Out:
# ['C:\\Users\\dinhh\\image.jpeg']
# ['.bash_history', '.condarc', '.gitconfig', '.lesshst', '.python_history', 'hi.html', 'image.jpeg', 'image.png', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini']

# %%
import matplotlib.pyplot as plt

p1 = plt.plot(dates, temp, 'r-', label="Temperature (celsius)")  
p2 = plt.plot(dates, psal, 'b-', label="Salinity (psu)")  
plt.legend(loc='upper center', numpoints=1, bbox_to_anchor=(0.5, -0.05),        ncol=2, fancybox=True, shadow=True)

plt.savefig('data.png')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16624/1112577071.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 p1 = plt.plot(dates, temp, 'r-', label="Temperature (celsius)")
#       4 p2 = plt.plot(dates, psal, 'b-', label="Salinity (psu)")
#       5 plt.legend(loc='upper center', numpoints=1, bbox_to_anchor=(0.5, -0.05),        ncol=2, fancybox=True, shadow=True)
#
# NameError: name 'dates' is not defined

# %%
from unidecode import unidecode
unidecode('t\u1ea1m bi\u1ec7t')
# Out:
# 'pythAPn!'

# %%
a = "Xin ch\u00e0o Hi\u1ebfu \ud83d\udc4b\ud83d\udc4b\ud83d\udc4b \nR\u1ea5t vui \u0111\u01b0\u1ee3c n\u00f3i chuy\u1ec7n v\u1edbi b\u1ea1n, t\u00f4i c\u00f3 th\u1ec3 gi\u00fap g\u00ec cho b\u1ea1n n\u00e0o "
'{"event": "bot", "timestamp": 1652177051.6905847, "text": "Xin ch\u00e0o Hi\u1ebfu \ud83d\udc4b\ud83d\udc4b\ud83d\udc4b \ud83e\udd35\ud83d\udc86\ud83d\udc77\ud83e\udd1e\ud83d\udc75\ud83d\udc81 \nR\u1ea5t vui \u0111\u01b0\u1ee3c n\u00f3i chuy\u1ec7n v\u1edbi b\u1ea1n, t\u00f4i c\u00f3 th\u1ec3 gi\u00fap g\u00ec cho b\u1ea1n n\u00e0o ", "data": {"elements": null, "quick_replies": null, "buttons": [{"type": "postback", "title": "Doanh thu", "payload": "C\u00f3 nh\u1eefng lo\u1ea1i doanh thu n\u00e0o"}, {"type": "postback", "title": "B\u1ea3ng l\u01b0\u01a1ng", "payload": "T\u00f4i mu\u1ed1n tr\u1ee3 gi\u00fap b\u1ea3ng l\u01b0\u01a1ng"}], "attachment": null, "image": null, "custom": null}, "metadata": {}}'.encode("utf-8", errors="replace").decode("utf-8").replace("?","").rstrip()
# Out:
# 'hieu{"event": "bot", "timestamp": 1652177051.6905847, "text": "Xin chào Hiếu   \nRất vui được nói chuyện với bạn, tôi có thể giúp gì cho bạn nào ", "data": {"elements": null, "quick_replies": null, "buttons": [{"type": "postback", "title": "Doanh thu", "payload": "Có những loại doanh thu nào"}, {"type": "postback", "title": "Bảng lương", "payload": "Tôi muốn trợ giúp bảng lương"}], "attachment": null, "image": null, "custom": null}, "metadata": {}}'

# %%
import yaml
# a = '{"event": "bot", "timestamp": 1652177051.6905847, "text": "Xin ch\u00e0o Hi\u1ebfu \ud83d\udc4b\ud83d\udc4b\ud83d\udc4b \ud83e\udd35\ud83d\udc86\ud83d\udc77\ud83e\udd1e\ud83d\udc75\ud83d\udc81 \nR\u1ea5t vui \u0111\u01b0\u1ee3c n\u00f3i chuy\u1ec7n v\u1edbi b\u1ea1n, t\u00f4i c\u00f3 th\u1ec3 gi\u00fap g\u00ec cho b\u1ea1n n\u00e0o ", "data": {"elements": null, "quick_replies": null, "buttons": [{"type": "postback", "title": "Doanh thu", "payload": "C\u00f3 nh\u1eefng lo\u1ea1i doanh thu n\u00e0o"}, {"type": "postback", "title": "B\u1ea3ng l\u01b0\u01a1ng", "payload": "T\u00f4i mu\u1ed1n tr\u1ee3 gi\u00fap b\u1ea3ng l\u01b0\u01a1ng"}], "attachment": null, "image": null, "custom": null}, "metadata": {}}'
a = yaml.safe_load('{"event": "user", "timestamp": 1652169778.8814292, "text": "ch\u00e0o", "parse_data": {"intent": {"id": 456111511838342261, "name": "greet", "confidence": 0.9990078806877136}, "entities": [], "text": "ch\u00e0o", "message_id": "88af009d765e4ba5807499f8c131ab47", "metadata": {}, "intent_ranking": [{"id": 456111511838342261, "name": "greet", "confidence": 0.9990078806877136}, {"id": 9088429289630049766, "name": "ask_dthu_store", "confidence": 0.00021907409245613962}, {"id": -8643125345980630723, "name": "ask_ctiet_ban_store", "confidence": 0.00019800153677351773}, {"id": 4243872148077146707, "name": "ask_salary_auto", "confidence": 0.00011655905836960301}, {"id": -3975033508525379336, "name": "ask_ctiet_ban", "confidence": 0.00011124402226414531}, {"id": -4123118997223314170, "name": "ask_dthu", "confidence": 0.0001027726975735277}, {"id": 1643063054080860034, "name": "ask_insert_salary_demo", "confidence": 7.428896060446277e-05}, {"id": 7894056859642633504, "name": "ask_salary", "confidence": 5.983221126371063e-05}, {"id": 5143778090369074869, "name": "ask_dthu_time_req", "confidence": 5.732624413212761e-05}, {"id": -3851156195851662424, "name": "ask_ctiet_ban_time_req", "confidence": 5.301163764670491e-05}], "response_selector": {"all_retrieval_intents": [], "default": {"response": {"id": null, "responses": null, "response_templates": null, "confidence": 0.0, "intent_response_key": null, "utter_action": "utter_None", "template_name": "utter_None"}, "ranking": []}}}, "input_channel": "facebook", "message_id": "88af009d765e4ba5807499f8c131ab47", "metadata": {}}')
a["text"]
a["timestamp"]
# Out:
# 1652169778.8814292
